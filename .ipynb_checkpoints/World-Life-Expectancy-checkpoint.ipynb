# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# df = pd.read_csv("world-data-2023.csv")
df = pd.read_csv('world-data-2023.csv')

# %%
# getting a first look at the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    int64
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    float64
#  4   Land Area(Km2)                             194 non-null    float64
#  5   Armed Forces size                          171 non-null    float64
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    float64
# ...

# %%
# checking the columns 
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 0  Afghanistan               60           AF                   0.58
# 1      Albania              105           AL                   0.43
# 2      Algeria               18           DZ                   0.17
# 3      Andorra              164           AD                   0.40
# 4       Angola               26           AO                   0.48
#
#    Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0        652230.0           323000.0       32.49          93.0
# 1         28748.0             9000.0       11.78         355.0
# 2       2381741.0           317000.0       24.28         213.0
# 3           468.0                NaN        7.20         376.0
# 4       1246700.0           117000.0       40.73         244.0
#
#   Capital/Major City  Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8672.0  ...                             0.78
# ...

# %%
# checking for duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Density
# (P/Km2), Abbreviation, Agricultural Land( %), Land Area(Km2), Armed Forces size, Birth Rate, Calling Code, Capital/Major City, Co2-Emissions, CPI, CPI Change (%), Currency-Code, Fertility Rate, Forested Area (%), Gasoline Price, GDP, Gross primary education enrollment (%), Gross tertiary education enrollment (%), Infant mortality, Largest city, Life expectancy, Maternal mortality ratio, Minimum wage, Official language, Out of pocket health expenditure, Physicians per thousand, Population, Population: Labor force participation (%), Tax revenue (%), Total tax rate, Unemployment rate, Urban_population, Latitude, Longitude]
# Index: []
#
# [0 rows x 35 columns]

# %%
# checking for nulls
df_missing = df.isnull().sum()
df_missing

# only using the following columns: life expectancy, unemployment rate, population, out of pocket health expediture, urban population, forested area, co2 emissions
# all these columns have a 96% non-null rate, except for unemployment has 90%
# Out:
# Country                                       0
# Density\n(P/Km2)                              0
# Abbreviation                                  7
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Calling Code                                  1
# Capital/Major City                            3
# Co2-Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Currency-Code                                15
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# ...

# %%
x=df['Country']
y=df['Life expectancy']
plt.bar(x,y)
plt.title('Life Expectancy per Country')
plt.xlabel('Country')
plt.ylabel('Age')
plt.show()

# %%
x=df['Life expectancy']
y=df['Population']
plt.bar(x,y)
plt.title('Life Expectancy vs. Population')
plt.xlabel('Life Expectancy')
plt.ylabel('Population')
plt.show()

# %%
x=df['Life expectancy']
y=df['Co2-Emissions']
plt.bar(x,y)
plt.title('Life Expectancy vs. Co2-Emissions')
plt.xlabel('Life Expenctancy')
plt.ylabel('Co2-Emissions')
plt.show()

# %%
x=df['Life expectancy']
y=df['Out of pocket health expenditure']
plt.bar(x,y)
plt.title('Life Expectancy vs. Out of pocket health expenditure')
plt.xlabel('Life Expectancy')
plt.ylabel('Out of pocket health expenditure')
plt.show()

# %%
x=df['Life expectancy']
y=df['Unemployment rate']
plt.bar(x,y)
plt.title('Life Expectancy vs. Unemployment Rate')
plt.xlabel('Life Expenctancy')
plt.ylabel('Unemployment Rate')
plt.show()

# %%
x=df['Life expectancy']
y=df['Forested Area (%)']
plt.bar(x,y)
plt.title('Life Expectancy vs. Forested Area')
plt.xlabel('Life Expenctancy')
plt.ylabel('Forest Area')
plt.show()

# %%
x=df['Life expectancy']
y=df['Urban_population']
plt.bar(x,y)
plt.title('Life Expectancy vs. Urban Population')
plt.xlabel('Life Expectancy')
plt.ylabel('Urban Population')
plt.show()
